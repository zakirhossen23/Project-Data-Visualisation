# %% [markdown]
# #DataFrame 1 for daily visitor data

# %% [markdown]
# 1: Reading csv
#
# 2: Converting into **DataFrame**
#
#
# ---

# %%
import pandas as pd
from matplotlib.patches import Patch

visitordata=pd.read_csv("https://raw.githubusercontent.com/ChrisWalshaw/DataViz/master/Data/001145733/VenueDailyVisitors.csv")

df=pd.DataFrame(visitordata)

df
# Out:
#            Date  UFY  XJT  XPE  AWF  AXM  BKI  XXO  WRL  ZJB  ...  QJL  WDZ  \
# 0    2019-01-01   60   83   95  198   61    0   89   78    0  ...  305   46
# 1    2019-01-02   62   78   71  169   65    0   95   90    0  ...  204  114
# 2    2019-01-03   69   72   75  120   57    0   92   68    0  ...  224  110
# 3    2019-01-04   61   80   97   99   46    0  100   67    0  ...  191   70
# 4    2019-01-05   53   90   85   90   65    0   91   92    0  ...  203  105
# ..          ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 360  2019-12-27   74   77   78   88   53   13    0   73  106  ...  165   82
# 361  2019-12-28   65  110   82   88   65    0    0   93   44  ...  199   73
# 362  2019-12-29   73   89   84  134   64  255    0   74    0  ...  220   95
# 363  2019-12-30   62   86   47  178   81  131    0   74  149  ...  326   81
# 364  2019-12-31   71   93   63  185   76  191    0   78   84  ...  304   64
#
#      UZO  WXV  CWN  VRD  YXF  YDI  WFI  TLJ
# 0     75   90  262   62   81    0   94   81
# 1     64   98  234   54   73    0   76   75
# 2     67   85  201   49   69    0   71   84
# 3     68   99  164   65   68    0   89   72
# 4     65   91  170   60   79    0   93   75
# ..   ...  ...  ...  ...  ...  ...  ...  ...
# 360   58  100  159   71   78   59   60   73
# 361   70  104  167   45   89   28   90   82
# 362   69   86  202   58   77  103   72   77
# 363   73  101  242   53   84  131   74   80
# 364   71  101  273   71   75   81   60   75
#
# [365 rows x 41 columns]

# %% [markdown]
# 1: Compressing Date. (eg. 30 days to 1 month)
#
# 2: Resampling dataframe with Mean for all the Venue Ids.
#
# 3: Converting Date to index(one row for each date)
#
#
# ---

# %%
df.index = pd.to_datetime(df['Date'])
df = df.resample('M').mean()
df = (df.set_index(df.index)
         .rename_axis("").T)
df
# Out:
#      2019-01-31  2019-02-28  2019-03-31  2019-04-30  2019-05-31  2019-06-30  \
# UFY   62.064516   62.892857   62.967742   63.000000   63.806452   65.133333
# XJT   78.419355   80.500000   80.000000   82.366667   81.806452   82.866667
# XPE   78.258065   74.821429   78.225806   75.466667   76.129032   79.800000
# AWF  140.193548  138.071429  135.870968  141.300000  138.258065  137.500000
# AXM   58.451613   63.357143   60.774194   61.133333   63.096774   61.133333
# BKI    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# XXO   93.483871   95.285714   94.677419   95.200000   96.612903   97.600000
# WRL   80.580645   76.642857   78.709677   75.100000   77.225806   76.800000
# ZJB    0.000000    0.000000    0.000000   16.533333   29.838710   40.533333
# PDT  252.580645  256.321429  260.903226  259.366667  276.387097  264.000000
# VLS   66.548387   68.035714   68.354839   68.100000   68.967742   69.666667
# TRV   75.967742   78.250000   73.806452   75.600000   75.645161   77.166667
# DKS  165.935484  169.178571  163.645161  178.400000  165.419355  153.866667
# SJU  500.096774  495.964286  490.741935  490.933333  491.129032  502.700000
# SPF  490.612903  455.428571  460.451613  465.000000  496.483871  482.466667
# BEY  173.709677  163.214286  165.193548  170.000000  164.741935  165.900000
# XFP   67.258065   67.928571   67.322581   68.633333   68.870968   69.233333
# QRY  228.322581  223.571429  234.129032  256.933333  249.322581  221.066667
# YVW    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# XLA   84.741935   84.161290   80.400000   84.387097   87.000000   84.709677
# QJL  231.258065  220.838710  227.100000  227.225806  217.966667  236.806452
# WDZ   80.903226   81.677419   82.066667   81.580645   79.766667   79.483871
# UZO   66.483871   65.483871   66.266667   66.064516   64.266667   67.387097
# WXV   93.935484   94.483871   94.933333   95.161290   95.433333   96.032258
# CWN  214.709677  208.161290  212.566667  213.935484  209.533333  215.580645
# VRD   59.193548   62.387097   61.466667   62.677419   61.366667   62.096774
# YXF   77.225806   76.258065   78.366667   80.161290   77.466667   80.419355
# YDI   36.838710   30.870968   59.866667   50.193548   79.900000   70.451613
# WFI   81.451613   82.290323   81.700000   82.193548   80.000000   77.741935
# TLJ   78.838710   79.064516   78.966667   79.000000   79.066667   79.000000

# %% [markdown]
#  **Visualizations**
#
# ---

# %% [markdown]
# **Normal Seasonality visualisation of Mean by *Monthly* view**

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(df)  
plt.show()

# %% [markdown]
# ***Averegare view of 12mos/1yr ***

# %%
df=pd.DataFrame(visitordata)
df = df.resample('A').mean()
df = (df.set_index(df.index)
         .rename_axis("").T)
df.plot()

# %% [markdown]
# # DataFrame 2 contain Summary Data

# %% [markdown]
# **Gathering all Datas into one DataFrame**
#
# ---

# %%
VenueAgeData=pd.read_csv("https://raw.githubusercontent.com/ChrisWalshaw/DataViz/master/Data/001145733/VenueAge.csv")
VenueDistanceData=pd.read_csv("https://raw.githubusercontent.com/ChrisWalshaw/DataViz/master/Data/001145733/VenueDistance.csv")
VenueDurationData=pd.read_csv("https://raw.githubusercontent.com/ChrisWalshaw/DataViz/master/Data/001145733/VenueDuration.csv")
VenueGenderData=pd.read_csv("https://raw.githubusercontent.com/ChrisWalshaw/DataViz/master/Data/001145733/VenueGender.csv")
VenueSpendData=pd.read_csv("https://raw.githubusercontent.com/ChrisWalshaw/DataViz/master/Data/001145733/VenueSpend.csv")

df2 = pd.DataFrame(VenueAgeData.pivot_table('Avg age (yrs)',[],'Id')) #Age Data
visitordata2 = visitordata.iloc[0:, 1:]
# Converting the index as date
visitordata2.index = visitordata2.index
visitordata2=visitordata2.resample('A').mean()
visitordata3 = visitordata2.reset_index().iloc[0:, 1:]
visitordata5 = pd.pivot_table(visitordata3,columns='Avg visit (yrs)').reset_index()
visitordata5.columns=['Id',"Avg visit (yrs)"]
df2 = df2.append(visitordata5.pivot_table('Avg visit (yrs)',[],'Id')) #Visitor Data

df2 = df2.append(VenueDistanceData.pivot_table('Max travel distance (mls)',[],'Id'))#Distance Data
df2 = df2.append(VenueDurationData.pivot_table('Avg visit duration (mins)',[],'Id'))#Duration Data
df2 = df2.append(VenueGenderData.pivot_table('Proportion Female (%)',[],'Id'))#Gender Data
df2 = df2.append(VenueSpendData.pivot_table('Avg spend (£)',[],'Id'))#Spend Data

df2
# Out:
# Id                               AEQ         AWF        AXM        BEY  \
# Avg age (yrs)              32.000000   48.000000  47.000000   39.00000
# Avg visit (yrs)            12.361644  139.616438  62.717808  166.29589
# Max travel distance (mls)   2.000000   11.000000   8.000000   18.00000
# Avg visit duration (mins)  88.000000  105.000000  90.000000  150.00000
# Proportion Female (%)      44.000000   54.000000  47.000000   60.00000
# Avg spend (£)              12.000000   19.000000  34.000000   18.00000
#
# Id                                BKI        BQV         CQC         CWN  \
# Avg age (yrs)               28.000000  47.000000   23.000000   35.000000
# Avg visit (yrs)             29.158904  41.909589  152.578082  211.153425
# Max travel distance (mls)    5.000000   5.000000   24.000000    9.000000
# Avg visit duration (mins)  101.000000  63.000000  122.000000   90.000000
# Proportion Female (%)       42.000000  42.000000   54.000000   59.000000
# Avg spend (£)               15.000000  30.000000    9.000000   16.000000
#
# Id                                DKS       GLQ  ...       XPE        XXO  \
# Avg age (yrs)               30.000000  23.00000  ...  52.00000  54.000000
# Avg visit (yrs)            164.013699  59.20274  ...  75.70137  47.342466
# Max travel distance (mls)   21.000000   3.00000  ...   4.00000   6.000000
# Avg visit duration (mins)   74.000000  92.00000  ...  83.00000  84.000000
# Proportion Female (%)       49.000000  44.00000  ...  46.00000  52.000000
# Avg spend (£)               23.000000  16.00000  ...  26.00000  38.000000
#
# Id                               YDI         YRU        YVW         YXF  \
# Avg age (yrs)              39.000000   35.000000  46.000000   23.000000
# Avg visit (yrs)            27.484932   64.145205  10.915068   76.758904
# Max travel distance (mls)   2.000000    6.000000   2.000000   12.000000
# Avg visit duration (mins)  64.000000  116.000000  91.000000  112.000000
# Proportion Female (%)      42.000000   49.000000  59.000000   44.000000
# Avg spend (£)              14.000000   14.000000  33.000000   13.000000
#
# Id                               ZFX         ZJB         ZLH         ZPL
# Avg age (yrs)              39.000000   35.000000   48.000000   25.000000
# Avg visit (yrs)            89.882192   33.378082   70.227397   28.315068
# Max travel distance (mls)   5.000000    5.000000    8.000000    3.000000
# Avg visit duration (mins)  79.000000  143.000000  137.000000  112.000000
# Proportion Female (%)      53.000000   58.000000   55.000000   55.000000
# Avg spend (£)              19.000000   27.000000   26.000000   17.000000
#
# [6 rows x 40 columns]

# %% [markdown]
# **Maximum status for all the Venue ID**
#
# ---

# %%
Maximum =df2.max(axis=1).to_frame()
Maximum = (Maximum.set_index(Maximum.index)
        .rename_axis(""))
MaximumVenue = df2.idxmax(axis=1).to_frame()
Maximum.head()
MaximumVenue.head()
# Out:
#                              0
# Avg age (yrs)              UFY
# Avg visit (yrs)            RDA
# Max travel distance (mls)  PXI
# Avg visit duration (mins)  BEY
# Proportion Female (%)      BEY

# %% [markdown]
#  **Visualizations**
#
# ---

# %%
ax = Maximum.plot(kind='bar',figsize=[8,8],legend=False)
plt.xticks(rotation=30, horizontalalignment="center")

x_offset = -0.28
y_offset = 1
for x in range(5):
    p =ax.patches[x]
    b = p.get_bbox()
    val = "{} - {}".format(MaximumVenue[0].values.tolist()[x], int(b.y1 ))
    ax.annotate(val, ((b.x0 + b.x1)/2 + x_offset, b.y1 + y_offset))

# %%
Maximum.plot(kind= legend=False)
plt.xticks(rotation=30, horizontalalignment="center")
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.]),
#  <a list of 8 Text major ticklabel objects>)
